# %% [markdown]
# #### Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
df=pd.read_excel('flight_price.xlsx')
num_rows, num_columns = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 10683
# Number of columns: 11

# %% [markdown]
# ####cQ2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df=pd.read_excel('flight_price.xlsx')
# Create a histogram to visualize the distribution of flight prices
plt.figure(figsize=(6, 3))
plt.hist(df['Price'], bins=20, color='green', edgecolor='black')
plt.xlabel('Flight Price')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
plt.show()

# %% [markdown]
# #### Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
# Calculate the range, minimum, and maximum price
price_range = df['Price'].max() - df['Price'].min()
min_price = df['Price'].min()
max_price = df['Price'].max()

# Print the results
print("Price Range:", price_range)
print("Minimum Price:", min_price)
print("Maximum Price:", max_price)
# Out:
# Price Range: 77753
# Minimum Price: 1759
# Maximum Price: 79512

# %% [markdown]
# #### Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of the plot
sns.set(style="whitegrid")

# Create a boxplot to compare flight prices by airline
plt.figure(figsize=(8, 4))
sns.boxplot(x="Airline", y="Price", data=df)
plt.xticks(rotation=45)
plt.title("Flight Prices by Airline")
plt.show()

# %% [markdown]
# #### Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
# Select the column containing the variable you want to analyze (e.g., "Price")
variable = "Price"

# Create a boxplot to identify potential outliers eg: Flight Price 
plt.figure(figsize=(6, 4))
sns.boxplot(x=df[variable])
plt.xlabel(variable)
plt.title("Boxplot of Flight Price")
plt.show()

# %% [markdown]
# Outliers can impact analysis by skewing statistical measures such as the mean and standard deviation, leading to inaccurate insights and predictions. It's important to identify and handle outliers appropriately, depending on their nature and impact on your analysis.

# %% [markdown]
# #### Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df=pd.read_excel('flight_price.xlsx')
# Convert the date column to datetime format
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])
# Extract the month and day from the 'Date_of_Journey' column
df['Month'] = df['Date_of_Journey'].dt.month
df['Day'] = df['Date_of_Journey'].dt.day
# Group the data by month and calculate the average flight price for each month
monthly_avg_price = df.groupby('Month')['Price'].mean()
# Visualize the average flight prices for each month
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(monthly_avg_price.index, monthly_avg_price.values, marker='o')
plt.xlabel('Month')
plt.ylabel('Average Flight Price')
plt.title('Average Flight Price by Month')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
# Convert 'Date_of_Journey' column to datetime format
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])

# Extract month from the date
df['Month'] =df['Date_of_Journey'].dt.month

# Map month to season
season_mapping = {
    12: 'Winter', 1: 'Winter', 2: 'Winter',
    3: 'Spring', 4: 'Spring', 5: 'Spring',
    6: 'Summer', 7: 'Summer', 8: 'Summer',
    9: 'Autumn', 10: 'Autumn', 11: 'Autumn'
}
df['Season'] = df['Month'].map(season_mapping)

# %%
# Group by season and calculate average flight price
season_price = df.groupby('Season')['Price'].mean()

# Display peak season
peak_season = season_price.idxmax()
print("Peak Season:", peak_season)
# Out:
# Peak Season: Winter

# %% [markdown]
# #### Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %%
# Line Plot for monthly flight price trend
plt.figure(figsize=(6, 4))
sns.lineplot(x='Date_of_Journey', y='Price', data=df)
plt.title('Monthly Flight Price Trend')
plt.xlabel('Date of Journey')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# Bar Plot for average flight price by airline
plt.figure(figsize=(6, 4))
sns.barplot(x='Airline', y='Price', data=df)
plt.title('Average Flight Price by Airline')
plt.xlabel('Airline')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# Box Plot for flight price distribution by number of stops
plt.figure(figsize=(6, 4))
sns.boxplot(x='Total_Stops', y='Price', data=df)
plt.title('Flight Price Distribution by Number of Stops')
plt.xlabel('Number of Stops')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# By analyzing these features and creating appropriate visualizations, we can identify trends and patterns in flight prices and effectively present the findings to our team.

# %% [markdown]
# #### Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of flight prices
plt.figure(figsize=(6, 4))
sns.histplot(df['Price'], bins=30, kde=True)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Distribution of Flight Prices")
plt.show()

# Relationship between Airline and Price
plt.figure(figsize=(6, 4))
sns.boxplot(x='Airline', y='Price', data=df)
plt.xticks(rotation=90)
plt.xlabel("Airline")
plt.ylabel("Price")
plt.title("Flight Price by Airline")
plt.show()

# Relationship between Number of Stops and Price
plt.figure(figsize=(6, 4))
sns.boxplot(x='Total_Stops', y='Price', data=df)
plt.xlabel("Number of Stops")
plt.ylabel("Price")
plt.title("Flight Price by Number of Stops")
plt.show()

# Relationship between Duration and Price
plt.figure(figsize=(6, 4))
sns.boxplot(x='Duration', y='Price', data=df)
plt.xlabel("Duration")
plt.ylabel("Price")
plt.title("Flight Price by Duration")
plt.show()

# %% [markdown]
# **Presenting Findings**
#
# To present the findings to the management team, we can create visualizations, summary statistics, and insights based on the analysis. We might use PowerPoint or Jupyter Notebook to create a presentation. Here's an example of how you could structure the presentation:
#
# Introduction:
#
# Brief overview of the dataset and the objective (identifying factors affecting flight prices).
#
# Distribution of Flight Prices:
#
# Present a histogram showing the distribution of flight prices.
# Mention key statistics like mean, median, and standard deviation.
#
# Factors Affecting Flight Prices:
#
# Visualize the relationship between features (Airline, Number of Stops, Cabin Class) and flight prices using boxplots.
# Highlight any significant trends or differences in prices based on these features.
#
#
# Seasonality and Demand:
#
# Discuss the potential impact of departure date and time on flight prices.
# Show any patterns or trends in flight prices based on seasons or demand.
#
# Conclusion:
#
# Summarize the key findings and factors that affect flight prices.
# Provide actionable insights and recommendations for the management team.

# %% [markdown]
# #### Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
num_rows, num_columns = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# #### Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# Drop rows with missing 'Rating' values
data_cleaned = df.dropna(subset=['Rating'])

# Display the first few rows of the cleaned dataset
print(data_cleaned.head())

# Set the style of seaborn
sns.set(style="whitegrid")

# Create a boxplot to compare ratings of different app categories
plt.figure(figsize=(6, 4))
sns.boxplot(x='Category', y='Rating', data=data_cleaned)
plt.xticks(rotation=90)
plt.title('Distribution of Ratings by App Category')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# #### Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("\nMissing values in each column:\n", missing_values)

# Calculate the percentage of missing values in each column
missing_percentage = (missing_values / df.shape[0]) * 100
print("\nPercentage of missing values in each column:\n", missing_percentage)
# Out:
# Missing values in each column:
#  App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64
#
# Percentage of missing values in each column:
#  App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64

# %% [markdown]
# The 'Rating' column has the maximum (13.6%) missing values followed by 'Current Ver' (0.07%), 'Android Ver' (0.02%), 'Type' and 'Content Rating' (0.01% each).
#
# Missing values can impact the analysis in various ways:
#
# Bias: If missing values are not handled properly, it can introduce bias in the analysis and modeling. For instance, if certain types of apps tend to have more missing values in a particular column, it can lead to biased insights about those apps.
#
# Reduced Sample Size: Missing values can reduce the effective sample size for analysis, which might lead to less accurate results.
#
# Model Performance: Missing values can affect the performance of machine learning models as many algorithms do not handle missing values well.
#
# Incorrect Insights: If not handled properly, missing values can distort the relationships between variables and lead to incorrect insights.

# %% [markdown]
# #### Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Google Playstore dataset
url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
data = pd.read_csv(url)

# Select the relevant columns
data_subset = data[['Rating', 'Size']]

# Drop rows with missing values
data_subset.dropna(inplace=True)

# Plot the scatter plot
plt.figure(figsize=(16, 4))
plt.scatter(data_subset['Size'], data_subset['Rating'], alpha=0.5)
plt.xlabel('Size')
plt.ylabel('Rating')
plt.title('Scatter Plot of App Size vs. Rating')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Google Playstore dataset
url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
data = pd.read_csv(url)

# Clean 'Price' column and convert to numeric
data['Price'] = data['Price'].apply(lambda x: x.replace('$', '') if '$' in str(x) else x)
data['Price'] = pd.to_numeric(data['Price'], errors='coerce')

# Group by app type and calculate average price
avg_price_by_type = data.groupby('Type')['Price'].mean()

# Create a bar chart
plt.figure(figsize=(6, 4))
avg_price_by_type.plot(kind='bar', color='blue')
plt.title("Average Prices by App Type")
plt.xlabel("App Type")
plt.ylabel("Average Price")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
import pandas as pd

# Load the Google Playstore dataset
url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
data = pd.read_csv(url)

# Create a frequency table of app names and installs
app_install_freq = data.groupby('App')['Installs'].sum().sort_values(ascending=False)

# Get the top 10 most popular apps
top_10_apps = app_install_freq.head(10)

# Display the top 10 most popular apps
print("Top 10 Most Popular Apps by Installs:")
print(top_10_apps)
# Out:
# Top 10 Most Popular Apps by Installs:
# App
# Life Made WI-Fi Touchscreen Photo Frame                                                     Free
# Candy Crush Saga                               500,000,000+500,000,000+500,000,000+500,000,00...
# Temple Run 2                                   500,000,000+500,000,000+500,000,000+500,000,00...
# Viber Messenger                                500,000,000+500,000,000+500,000,000+500,000,00...
# Snapchat                                        500,000,000+500,000,000+500,000,000+500,000,000+
# imo free video calls and chat                   500,000,000+500,000,000+500,000,000+500,000,000+
# Pou                                             500,000,000+500,000,000+500,000,000+500,000,000+
# UC Browser - Fast Download Private & Secure                 500,000,000+500,000,000+500,000,000+
# LINE: Free Calls & Messages                                 500,000,000+500,000,000+500,000,000+
# ...

# %% [markdown]
# #### Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %%
import pandas as pd

# Load the Google Playstore dataset
url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
data = pd.read_csv(url)

# Count the number of apps in each category
category_counts = data['Category'].value_counts()

# Display the top 10 most popular app categories
top_categories = category_counts.head(10)
print("Top 10 Most Popular App Categories:")
print(top_categories)

import matplotlib.pyplot as plt

# Plot the top 10 app categories
plt.figure(figsize=(6, 4))
top_categories.plot(kind='bar', color='skyblue')
plt.xlabel("App Category")
plt.ylabel("Number of Apps")
plt.title("Top 10 Most Popular App Categories")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Top 10 Most Popular App Categories:
# FAMILY             1972
# GAME               1144
# TOOLS               843
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     392
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: Category, dtype: int64

# %% [markdown]
# #### Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df=df.drop(df.index[10472])
df['Reviews']=df['Reviews'].astype(int)
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df[cols]=df[cols].str.replace(item,'')
        
df['Installs']=df['Installs'].astype('int')
df['Price']=df['Price'].astype('float')

df = df.dropna(subset=['App', 'Installs', 'Rating', 'Reviews', 'Category'])


# Group by app and calculate the total installs and average rating
app_performance = df.groupby('App').agg({'Installs': 'sum', 'Rating': 'mean'}).sort_values(by='Installs', ascending=False).head(10)

# Plot total installs and average rating for top apps
plt.figure(figsize=(10, 6))
sns.barplot(data=app_performance, x='Installs', y=app_performance.index, palette='viridis')
plt.xlabel("Total Installs")
plt.ylabel("App")
plt.title("Top 10 Most Successful Apps")
plt.tight_layout()
plt.show()

# Group by category and calculate the total reviews
category_reviews = df.groupby('Category')['Reviews'].sum().sort_values(ascending=False)

# Plot total reviews by category
plt.figure(figsize=(6, 4))
category_reviews.plot(kind='bar', color='c')
plt.xlabel("Category")
plt.ylabel("Total Reviews")
plt.title("Total Reviews by Category")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

df = df.groupby(['Category' ,'App'])['Installs'].sum().reset_index()
df = df.sort_values('Installs', ascending = False)
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(30, 20))

for i,app in enumerate(apps):
    df2 = df[df.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)

plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %% [markdown]
# #### Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df=df.drop(df.index[10472])
df['Reviews']=df['Reviews'].astype(int)
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df[cols]=df[cols].str.replace(item,'')
        
df['Installs']=df['Installs'].astype('int')
df['Price']=df['Price'].astype('float')

df = df.dropna(subset=['App', 'Installs', 'Rating', 'Reviews', 'Category'])

df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Day'] = df['Last Updated'].dt.day
df['Month'] = df['Last Updated'].dt.month
df['Year'] = df['Last Updated'].dt.year


import matplotlib.pyplot as plt

# Group by month and calculate the total number of installs
user_activity = df.groupby(df['Month']).agg({'Installs': 'sum'})

# Plot user activity over time
plt.figure(figsize=(6, 4))
plt.plot(user_activity.index, user_activity['Installs'], marker='o')
plt.xlabel("Month")
plt.ylabel("Total Installs")
plt.title("User Activity Over Time")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# Group by month and calculate the average rating and total reviews
app_updates_and_reviews = df.groupby(df['Month']).agg({'Rating': 'mean', 'Reviews': 'sum'})

# Plot app updates and user reviews over time
fig, ax1 = plt.subplots(figsize=(6, 4))

color = 'tab:blue'
ax1.set_xlabel("Month")
ax1.set_ylabel("Average Rating", color=color)
ax1.plot(app_updates_and_reviews.index, app_updates_and_reviews['Rating'], color=color, marker='o')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel("Total Reviews", color=color)
ax2.plot(app_updates_and_reviews.index, app_updates_and_reviews['Reviews'], color=color, marker='s')
ax2.tick_params(axis='y', labelcolor=color)

plt.title("App Updates and User Reviews Over Time")
plt.grid(True)
plt.tight_layout()
plt.show()


# Group by day of week and calculate the median installs
day_of_week_analysis = df.groupby(df['Last Updated'].dt.dayofweek).agg({'Installs': 'median'})

# Rename day of week labels
day_of_week_analysis.index = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Plot median installs by day of week
plt.figure(figsize=(6, 4))
day_of_week_analysis['Installs'].plot(kind='bar')
plt.xlabel("Day of Week")
plt.ylabel("Median Installs")
plt.title("Median Installs by Day of Week")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()


# Calculate days since last update
df['Days Since Update'] = (pd.Timestamp.now() - df['Last Updated']).dt.days

# Plot installs against days since last update
plt.figure(figsize=(6, 4))
plt.scatter(df['Days Since Update'], df['Installs'], alpha=0.5)
plt.xlabel("Days Since Last Update")
plt.ylabel("Installs")
plt.title("Installs vs Days Since Last Update")
plt.grid(True)
plt.tight_layout()
plt.show()
